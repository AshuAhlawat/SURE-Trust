# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./kc_house_data.csv")
n = len(df)


inputs = df.drop(["id","date","zipcode","lat","long","sqft_living15","sqft_lot15"], axis = 1)
targets = inputs[["price","grade"]]
inputs = inputs.drop(["price","grade"],axis= 1)

org_mean, org_std = targets.mean(), targets.std()

targets = targets - targets.mean()
targets = targets/targets.std()

targets.describe()
# Out:
#               price         grade
# count  2.161300e+04  2.161300e+04
# mean  -3.419074e-17  1.788439e-16
# std    1.000000e+00  1.000000e+00
# min   -1.266831e+00 -5.663213e+00
# 25%   -5.941759e-01 -5.588228e-01
# 50%   -2.453867e-01 -5.588228e-01
# 75%    2.857643e-01  2.919089e-01
# max    1.950254e+01  4.545567e+00

# %%
x = inputs[["sqft_living","sqft_lot","sqft_above","sqft_basement","yr_built","yr_renovated"]]

inputs[["sqft_living","sqft_lot","sqft_above","sqft_basement","yr_built","yr_renovated"]] = (x - x.mean())/x.std()

# %%
inputs
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0             3       1.00    -0.979812 -0.228316     1.0           0     0
# 1             3       2.25     0.533622 -0.189881     2.0           0     0
# 2             2       1.00    -1.426221 -0.123296     1.0           0     0
# 3             4       3.00    -0.130547 -0.244009     1.0           0     0
# 4             3       2.00    -0.435412 -0.169649     1.0           0     0
# ...         ...        ...          ...       ...     ...         ...   ...
# 21608         3       2.50    -0.598732 -0.337417     3.0           0     0
# 21609         4       2.50     0.250534 -0.224381     2.0           0     0
# 21610         2       0.75    -1.154021 -0.332129     2.0           0     0
# 21611         3       2.50    -0.522516 -0.307069     2.0           0     0
# 21612         2       0.75    -1.154021 -0.338744     2.0           0     0
#
#        condition  sqft_above  sqft_basement  yr_built  yr_renovated
# 0              3   -0.734691      -0.658666 -0.544885     -0.210124
# 1              3    0.460830       0.245136 -0.681063      4.746568
# 2              3   -1.229805      -0.658666 -1.293862     -0.210124
# 3              5   -0.891678       1.397483 -0.204441     -0.210124
# 4              3   -0.130892      -0.658666  0.544535     -0.210124
# ...          ...         ...            ...       ...           ...
# 21608          3   -0.312032      -0.658666  1.293512     -0.210124
# 21609          3    0.629894      -0.658666  1.463734     -0.210124
# 21610          3   -0.927906      -0.658666  1.293512     -0.210124
# 21611          3   -0.227500      -0.658666  1.123290     -0.210124
# 21612          3   -0.927906      -0.658666  1.259468     -0.210124
#
# [21613 rows x 12 columns]

# %%
def predict(x, weights, bias):
    pred = np.dot(x, weights.T) + bias

    predictions_df = pd.DataFrame(pred, columns=["price", "grade"])

    return predictions_df


def mean_squared_error(predictions_df, targets):
    se_df = (predictions_df - targets)**2

    mse = se_df.mean()
    
    return mse

# %%
def w_gradient(inputs, targets, predictions):
    grads = np.zeros((2,12))
    
    
    for i,y in enumerate(targets.columns):
        for j,X in enumerate(inputs.columns):
        
            grad = (-2*( (targets - predictions)[y] )*inputs[X]).mean()
            grads[i,j] = grad
            
    return grads


def b_gradient(targets, predictions):
    grad = np.zeros((1,2))
    
    for i, y in enumerate(targets.columns):
        grad[0, i] = (-2 * (targets[y] - predictions[y])).mean()
        
    return grad

# %%
weights = np.random.normal(size= (2,12))
bias = np.random.normal(size= (1,2))

weights, bias
# Out:
# (array([[-2.5267656 , -1.12481803, -1.51385624, -1.48188878,  0.36877993,
#          -0.57060744,  0.27455965,  0.70905543,  0.20531223, -0.40393738,
#           0.32427741,  0.04029159],
#         [ 1.44427272,  0.029775  ,  0.79945535,  0.67083234,  0.2943903 ,
#           0.32187463,  1.0042812 ,  0.35216895,  0.65653979,  0.46445747,
#          -1.64870705, -0.94437502]]),
#  array([[-2.0561114 , -0.01091961]]))

# %%
history = []

# %%
lr = 0.001


for i in tqdm(range(10000)):
    
    # make a prediction
    prediction = predict(inputs, weights, bias)
    
    # calculate and print the loss
    loss = mean_squared_error(targets, prediction)
        
    # calculate gradients
    w_grad = w_gradient(inputs, targets, prediction)
    
    b_grad = b_gradient(targets,prediction)
    
    weights = weights - lr * w_grad
    bias = bias - lr * b_grad
    
    history.append({"Price":loss["price"], "Grade":loss["grade"]})
    
    # if (i+1)%100 == 0:
    #     print(loss)
    # update weights and biases using the gradients
    
    
# output the least loss u could get, tweak the learning rate if u want
# Out:
# 100%|██████████| 10000/10000 [01:59<00:00, 83.52it/s]

# %%
history_df = pd.DataFrame(history)


history_df["Price"].plot(kind="line")
plt.ylabel("Loss")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
prediction = np.array(inputs.iloc[427])@weights.T + bias

(prediction*[org_std] + [org_mean])[0]
# Out:
# array([5.52889215e+05, 7.76622194e+00])
